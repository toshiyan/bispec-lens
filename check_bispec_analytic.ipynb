# %%
import numpy as np
from matplotlib.pyplot import *

# %%
z, zker, chi, hz, wlens, prod, wlens2, wlens3 = np.loadtxt('test.dat',unpack=True)
Z, Zker, Chi, Hz, Wlens, Prod = np.loadtxt('xbisp/zker.dat',unpack=True)

# %%
yscale('log')
plot(z,zker)
plot(Z,Zker/2)

# %%
z, zker, dndz = np.loadtxt('test.dat',unpack=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-ed7ef8f06f35> in <module>
# ----> 1 z, zker, dndz = np.loadtxt('test.dat',unpack=True)
#
# ValueError: too many values to unpack (expected 3)

# %%
Z, Clker, Zker, Dndz = np.loadtxt('xbisp/kernel.dat',unpack=True)

# %%
yscale('log')
#xscale('log')
plot(z,zker)
plot(Z,Zker/2)

# %%
plot(z,dndz)
plot(Z,Dndz)
